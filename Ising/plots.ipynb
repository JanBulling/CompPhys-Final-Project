# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#staggered_susc_teset:

df_antiferro = pd.read_csv("data/J-6p903245000000001e-22_B4p141947e-22_nTherm400_nSamp100_Metropolis20_freshStarts10_1/res_N_8.csv")
df_ferro = pd.read_csv("data/J6p903245000000001e-22_B4p141947e-22_nTherm400_nSamp100_Metropolis20_freshStarts10_1/res_N_8.csv")


plt.errorbar(df_antiferro["T"],df_antiferro["staggered_susceptibility"], yerr=df_antiferro["staggered_susceptibility_std"], label="AFM with Field")
# plt.errorbar(df_antiferro_16["T"],df_antiferro_16["susceptibility"], yerr=df_antiferro_16["susceptibility_std"], label="16")

plt.errorbar(df_ferro["T"],df_ferro["susceptibility"], yerr=df_ferro["susceptibility_std"], label="FM with Field")

plt.legend(loc='best')
plt.show()

plt.plot(df_ferro["T"],df_ferro["susceptibility_std"])
# plt.plot(df_antiferro["T"], df_antiferro["staggered_susceptibility_std"])

# %%
#staggered_susc_teset:

df_antiferro = pd.read_csv("data/J-6p903245000000001e-22_B0_nTherm400_nSamp100_Metropolis20_freshStarts10_1/res_N_8.csv")
df_ferro = pd.read_csv("data/J6p903245000000001e-22_B0_nTherm400_nSamp100_Metropolis20_freshStarts10_1/res_N_8.csv")


plt.errorbar(df_antiferro["T"],df_antiferro["staggered_susceptibility"], yerr=df_antiferro["staggered_susceptibility_std"], label="AFM without Field")
# plt.errorbar(df_antiferro_16["T"],df_antiferro_16["susceptibility"], yerr=df_antiferro_16["susceptibility_std"], label="16")

plt.errorbar(df_ferro["T"],df_ferro["susceptibility"], yerr=df_ferro["susceptibility_std"], label="FM without Field")

plt.legend(loc='best')
plt.show()

plt.plot(df_ferro["T"],df_ferro["susceptibility_std"])
# plt.plot(df_antiferro["T"], df_antiferro["staggered_susceptibility_std"])
